# %%
import pandas as pd 

personas= pd.read_csv("https://datasets.datos.mincyt.gob.ar/dataset/06ae9728-c376-47bd-9c41-fbdca68707c6/resource/11dca5bb-9a5f-4da5-b040-28957126be18/download/personas_2011.csv", sep=";")

# %%
personas.head(15)#Devuelve los 1eros 5 valores
# Out:
#     persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0            1  2011        2    36                         -1
# 1            5  2011        1    48                          1
# 2            7  2011        2    30                          5
# 3           10  2011        2    51                          5
# 4           11  2011        1    39                          2
# 5           12  2011        2    48                          1
# 6           13  2011        2    41                          5
# 7           15  2011        1    46                          1
# 8           17  2011        2    53                          2
# 9           19  2011        2    52                          1
# 10          21  2011        1    34                          1
# 11          22  2011        2    33                          1
# 12          23  2011        2    58                          1
# 13          24  2011        2    53                          1
# ...

# %%
personas.describe() #Esta funcion te perimite obtener "Count", "Mean", "std", "min", etc. de cada columna de la tabla si es un valor numerico
# Out:
#           persona_id     anio       sexo_id          edad  \
# count   68552.000000  68552.0  68552.000000  68552.000000
# mean    52537.987280   2011.0      1.423430     38.475172
# std     40279.541919      0.0      0.494106     12.483655
# min         1.000000   2011.0      1.000000     -1.000000
# 25%     22112.500000   2011.0      1.000000     29.000000
# 50%     44284.500000   2011.0      1.000000     37.000000
# 75%     73350.250000   2011.0      2.000000     48.000000
# max    185608.000000   2011.0      2.000000     88.000000
#
#        maximo_grado_academico_id  disciplina_maximo_grado_academico_id  \
# count               68552.000000                          68552.000000
# mean                    3.306847                            152.966726
# std                     2.258145                            112.218458
# min                    -1.000000                             -1.000000
# 25%                     1.000000                             26.000000
# ...

# %%
#te devuelve sus tipos de datos y el número de valores no nulos en cada columna
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68552 entries, 0 to 68551
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   persona_id                            68552 non-null  int64
#  1   anio                                  68552 non-null  int64
#  2   sexo_id                               68552 non-null  int64
#  3   edad                                  68552 non-null  int64
#  4   maximo_grado_academico_id             68552 non-null  int64
#  5   disciplina_maximo_grado_academico_id  68552 non-null  int64
#  6   disciplina_titulo_grado_id            68552 non-null  int64
#  7   disciplina_experticia_id              68552 non-null  int64
#  8   tipo_personal_id                      68552 non-null  int64
#  9   producciones_ult_anio                 68552 non-null  int64
#  10  producciones_ult_2_anios              68552 non-null  int64
# ...

# %%
personas.head()
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# ...

# %%
personas["seniority_level"].count()#obtiene el recuento de cada grupo ignorando los valores ninguno y Nan
# Out:
# 68552

# %%
personas.groupby("seniority_level").count()#agrupa cada valor dentro de la clave”seniority_level”, pone cada una en una fila( sin repetir) y me da los valores de cada una de las otras claves correspondientes a cada una de ellas en su misma fila pero en la columna de la clave que se este analizando (sin repetir)(sin contar los Nan gracias a count())
# Out:
#                  persona_id   anio  sexo_id   edad  maximo_grado_academico_id  \
# seniority_level
#                       33085  33085    33085  33085                      33085
# A                      4834   4834     4834   4834                       4834
# B                      6674   6674     6674   6674                       6674
# C                     13645  13645    13645  13645                      13645
# D                      5774   5774     5774   5774                       5774
# S/D                    4540   4540     4540   4540                       4540
#
#                  disciplina_maximo_grado_academico_id  \
# seniority_level
#                                                 33085
# A                                                4834
# B                                                6674
# C                                               13645
# D                                                5774
# S/D                                              4540
#
# ...

# %%
personas.groupby("seniority_level")[["persona_id"]].count() #agrupa cada valor dentro de la clave "seniority_level", pone cada una en una fila( sin repetir) y me da los valores de la clave "persona_id" correspondientes a cada una de ellas en su misma fila pero en la columna de la clave "persona_id" (sin repetir)(sin contar los Nan gracias a count())
# Out:
#                  persona_id
# seniority_level
#                       33085
# A                      4834
# B                      6674
# C                     13645
# D                      5774
# S/D                    4540

# %%
personas.head()
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# ...

# %%
personas['edad'] * 2 #multiplica cada edad al doble
# Out:
# 0         72
# 1         96
# 2         60
# 3        102
# 4         78
#         ...
# 68547     -2
# 68548    110
# 68549     36
# 68550     -2
# 68551     54
# Name: edad, Length: 68552, dtype: int64

# %%
personas['edad'] + 2 #a cada edad le suma 2
# Out:
# 0        38
# 1        50
# 2        32
# 3        53
# 4        41
#          ..
# 68547     1
# 68548    57
# 68549    20
# 68550     1
# 68551    29
# Name: edad, Length: 68552, dtype: int64

# %%
personas['edad'] > 2 #si la edad es mayor a 2 devuelve True sino false
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 68547    False
# 68548     True
# 68549     True
# 68550    False
# 68551     True
# Name: edad, Length: 68552, dtype: bool

# %%
personas[personas['edad'] < 35 ] #me muestra tabla solamente con datos de las personas <35 años
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 2               7  2011        2    30                          5
# 10             21  2011        1    34                          1
# 11             22  2011        2    33                          1
# 24             42  2011        2    34                          1
# 26             45  2011        2    25                          5
# ...           ...   ...      ...   ...                        ...
# 68546      185534  2011        2    -1                         -1
# 68547      185558  2011        2    -1                         -1
# 68549      185583  2011        2    18                          7
# 68550      185590  2011        2    -1                          8
# 68551      185608  2011        1    27                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 2                                       111                         111
# ...

# %%
personas.head()
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# ...

# %%
import pandas as pd

personas= pd.read_csv("https://datasets.datos.mincyt.gob.ar/dataset/06ae9728-c376-47bd-9c41-fbdca68707c6/resource/11dca5bb-9a5f-4da5-b040-28957126be18/download/personas_2011.csv", sep=";")

# %%
import pandas as pd

categorias= pd.read_csv("https://datasets.datos.mincyt.gob.ar/dataset/06ae9728-c376-47bd-9c41-fbdca68707c6/resource/c72c9f88-d9ef-4349-bb20-5c9a1aca5d67/download/ref_categoria_conicet.csv", sep=";")

# %%
personas_cat = pd.merge(personas, categorias, on='categoria_conicet_id')
#filtrando por categoria de conicet, en este caso podemos combinar las dos tablas
#de modo de saber qué valores de categoria_conicet_id se corresponde con cada categoria de conicet

#agrega a tabla de df personas, la columna categoria_conicet_id con su correspondiente categoria de conicet

# %%
personas_cat
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 48340       76784  2011        1    32                          5
# 48341       76842  2011        2    30                          5
# 48342       76892  2011        1    29                          5
# 48343       76897  2011        2    27                          2
# 48344       76904  2011        1    26                          2
# ...           ...   ...      ...   ...                        ...
# 48635       60260  2011        1    34                          5
# 48636       79131  2011        1    38                          3
# 48637       85209  2011        1    40                          1
# 48638      146747  2011        2    32                          3
# 48639       47272  2011        1    28                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 48340                                    -1                          -1
# ...

# %%
personas_cat = pd.concat([personas, categorias])
#agrega a tabla de df personas, la columna categoria_conicet_id con su correspondiente categoria o en caso de no pertenecer NaN

# %%
personas_cat
# Out:
#        persona_id    anio  sexo_id  edad  maximo_grado_academico_id  \
# 68266    181077.0  2011.0      1.0  -1.0                       -1.0
# 68267    181084.0  2011.0      2.0  42.0                        3.0
# 68268    181089.0  2011.0      1.0  25.0                        5.0
# 68269    181093.0  2011.0      2.0  52.0                        3.0
# 68270    181097.0  2011.0      1.0  50.0                        5.0
# ...           ...     ...      ...   ...                        ...
# 9             NaN     NaN      NaN   NaN                        NaN
# 10            NaN     NaN      NaN   NaN                        NaN
# 11            NaN     NaN      NaN   NaN                        NaN
# 12            NaN     NaN      NaN   NaN                        NaN
# 13            NaN     NaN      NaN   NaN                        NaN
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 68266                                  -1.0                        -1.0
# ...

# %%
personas.head(20)
# Out:
#     persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0            1  2011        2    36                         -1
# 1            5  2011        1    48                          1
# 2            7  2011        2    30                          5
# 3           10  2011        2    51                          5
# 4           11  2011        1    39                          2
# 5           12  2011        2    48                          1
# 6           13  2011        2    41                          5
# 7           15  2011        1    46                          1
# 8           17  2011        2    53                          2
# 9           19  2011        2    52                          1
# 10          21  2011        1    34                          1
# 11          22  2011        2    33                          1
# 12          23  2011        2    58                          1
# 13          24  2011        2    53                          1
# ...

# %%
categoria_a = personas[personas["seniority_level"].str.contains("A")]
categoria_b = personas[personas["seniority_level"].str.contains("B")]

pd.concat([categoria_a, categoria_b])
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 9              19  2011        2    52                          1
# 12             23  2011        2    58                          1
# 15             26  2011        1    60                          1
# 16             27  2011        1    51                          5
# 19             32  2011        1    47                          1
# ...           ...   ...      ...   ...                        ...
# 68080      179905  2011        1    48                          1
# 68123      180191  2011        1    47                          1
# 68151      180414  2011        1    55                          2
# 68374      181894  2011        1    49                          2
# 68401      182042  2011        1    49                          2
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 9                                       255                         255
# ...

# %%
list(personas)
# Out:
# ['persona_id',
#  'anio',
#  'sexo_id',
#  'edad',
#  'maximo_grado_academico_id',
#  'disciplina_maximo_grado_academico_id',
#  'disciplina_titulo_grado_id',
#  'disciplina_experticia_id',
#  'tipo_personal_id',
#  'producciones_ult_anio',
#  'producciones_ult_2_anios',
#  'producciones_ult_3_anios',
#  'producciones_ult_4_anios',
#  'institucion_trabajo_id',
#  'seniority_level',
#  'categoria_conicet_id',
#  'categoria_incentivos',
#  'max_dedicacion_horaria_docente_id',
#  'institucion_cargo_docente_id',
#  'clase_cargo_docente_id',
#  'tipo_condicion_docente_id']

# %%
personas.edad
# Out:
# 0        36
# 1        48
# 2        30
# 3        51
# 4        39
#          ..
# 68547    -1
# 68548    55
# 68549    18
# 68550    -1
# 68551    27
# Name: edad, Length: 68552, dtype: int64

# %%
personas["edad"].median()
# Out:
# 37.0

# %%
personas.isnull().sum()#vamos a intentar cuantificar cuántas celdas hayen nuetsra tabla sin información
# Out:
# persona_id                                  0
# anio                                        0
# sexo_id                                     0
# edad                                        0
# maximo_grado_academico_id                   0
# disciplina_maximo_grado_academico_id        0
# disciplina_titulo_grado_id                  0
# disciplina_experticia_id                    0
# tipo_personal_id                            0
# producciones_ult_anio                       0
# producciones_ult_2_anios                    0
# producciones_ult_3_anios                    0
# producciones_ult_4_anios                    0
# institucion_trabajo_id                      0
# seniority_level                             0
# categoria_conicet_id                    19912
# categoria_incentivos                    19912
# max_dedicacion_horaria_docente_id       19912
# institucion_cargo_docente_id            19912
# clase_cargo_docente_id                  19912
# ...

# %%
#Grafico para saber donde estan los datos nulos en q columna y en que fila

import seaborn as sns  #inspección de los datos de forma visual

sns.heatmap(personas.isnull(), cmap='viridis') #Aux: Cmap:color
# Out:
# <AxesSubplot:>

# %%
personas.head(35)
# Out:
#     persona_id  anio  sexo_id  edad  disciplina_maximo_grado_academico_id  \
# 0            1  2011        2    36                                    -1
# 1            5  2011        1    48                                   255
# 3           10  2011        2    51                                   248
# 4           11  2011        1    39                                   223
# 5           12  2011        2    48                                    58
# 6           13  2011        2    41                                   192
# 7           15  2011        1    46                                   258
# 8           17  2011        2    53                                   281
# 9           19  2011        2    52                                   255
# 10          21  2011        1    34                                    40
# 11          22  2011        2    33                                    65
# 12          23  2011        2    58                                   256
# ...

# %%
personas.dropna(inplace=True)  #elimina todas las filas que contienen un dato faltante

# %%
personas.dropna(thresh=2, inplace=True) #elimina todas las filas que contienen mas de un dato faltante

# %%
personas.drop(["maximo_grado_academico_id"], axis=1, inplace=True)#eliminación por columna al encontrar dato faltante

# %%
personas.isnull().sum() #en este caso aparecen todos 0 xq en el anterior elimine los de datos faltantes
# Out:
# persona_id                              0
# anio                                    0
# sexo_id                                 0
# edad                                    0
# maximo_grado_academico_id               0
# disciplina_maximo_grado_academico_id    0
# disciplina_titulo_grado_id              0
# disciplina_experticia_id                0
# tipo_personal_id                        0
# producciones_ult_anio                   0
# producciones_ult_2_anios                0
# producciones_ult_3_anios                0
# producciones_ult_4_anios                0
# institucion_trabajo_id                  0
# seniority_level                         0
# categoria_conicet_id                    0
# categoria_incentivos                    0
# max_dedicacion_horaria_docente_id       0
# institucion_cargo_docente_id            0
# clase_cargo_docente_id                  0
# tipo_condicion_docente_id               0
# dtype: int64

# %%
df.fillna(df['columna_con_faltantes'].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\notebook\OneDrive\Documents\GitHub\fundamento_de_informatica 2do parcial\ciencia_datos\clasespandas.ipynb Cell 31' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/notebook/OneDrive/Documents/GitHub/fundamento_de_informatica%202do%20parcial/ciencia_datos/clasespandas.ipynb#ch0000052?line=0'>1</a> df.fillna(df['columna_con_faltantes'].mean(), inplace=True)
#
# NameError: name 'df' is not defined

# %%
#como se convierte un tipo de dato de una columna en otro?
personas["seniority_level"] = personas["seniority_level"].astype("string")
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68552 entries, 0 to 68551
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   persona_id                            68552 non-null  int64
#  1   anio                                  68552 non-null  int64
#  2   sexo_id                               68552 non-null  int64
#  3   edad                                  68552 non-null  int64
#  4   maximo_grado_academico_id             68552 non-null  int64
#  5   disciplina_maximo_grado_academico_id  68552 non-null  int64
#  6   disciplina_titulo_grado_id            68552 non-null  int64
#  7   disciplina_experticia_id              68552 non-null  int64
#  8   tipo_personal_id                      68552 non-null  int64
#  9   producciones_ult_anio                 68552 non-null  int64
#  10  producciones_ult_2_anios              68552 non-null  int64
# ...

# %%
#Lo q hace es filtrar la tabla de personas primero por rl sexo = 1 y luego para edad < 40 ---> despues se agarra la culumna "producciones_ult_4_anios" y con el .mean() --> obtenemos la media.
personas[(personas["sexo_id"] == 1) & (personas["edad"]< 40)]["producciones_ult_4_anios"].mean()
# Out:
# 4.099082811535409

# %%
#Metodo para filtrar en columnas tipo str 
personas[personas["seniority_level"].str.contains("A")]
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 9              19  2011        2    52                          1
# 12             23  2011        2    58                          1
# 15             26  2011        1    60                          1
# 16             27  2011        1    51                          5
# 19             32  2011        1    47                          1
# ...           ...   ...      ...   ...                        ...
# 65935      150413  2011        1    57                          2
# 65948      151054  2011        1    49                          3
# 65983      152466  2011        1    39                          5
# 67557      176778  2011        1    51                          2
# 68438      182436  2011        1    57                          2
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 9                                       255                         255
# ...

# %%
# .loc funciona para imprimir 1 valor exacto de la tabla Fila(19) y Columna(personas_id)
personas.loc[19, "seniority_level"]
# Out:
# 'A  '

# %%
personas.loc[19]
# Out:
# persona_id                                 32
# anio                                     2011
# sexo_id                                     1
# edad                                       47
# maximo_grado_academico_id                   1
# disciplina_maximo_grado_academico_id      106
# disciplina_titulo_grado_id                 38
# disciplina_experticia_id                   38
# tipo_personal_id                            3
# producciones_ult_anio                      11
# producciones_ult_2_anios                   19
# producciones_ult_3_anios                   21
# producciones_ult_4_anios                   23
# institucion_trabajo_id                    877
# seniority_level                           A
# categoria_conicet_id                      3.0
# categoria_incentivos                      2.0
# max_dedicacion_horaria_docente_id         3.0
# institucion_cargo_docente_id            356.0
# clase_cargo_docente_id                   69.0
# ...

# %%
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 9              19  2011        2    52                          1
# 12             23  2011        2    58                          1
# 15             26  2011        1    60                          1
# 16             27  2011        1    51                          5
# 19             32  2011        1    47                          1
# ...           ...   ...      ...   ...                        ...
# 68080      179905  2011        1    48                          1
# 68123      180191  2011        1    47                          1
# 68151      180414  2011        1    55                          2
# 68374      181894  2011        1    49                          2
# 68401      182042  2011        1    49                          2
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 9                                       255                         255
# ...

# %%
personas.head(300)
# Out:
#      persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0             1  2011        2    36                         -1
# 1             5  2011        1    48                          1
# 2             7  2011        2    30                          5
# 3            10  2011        2    51                          5
# 4            11  2011        1    39                          2
# ..          ...   ...      ...   ...                        ...
# 295         442  2011        2    27                          5
# 296         443  2011        2    56                          1
# 297         444  2011        2    56                          1
# 298         445  2011        2    67                          5
# 299         446  2011        1    48                          1
#
#      disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                      -1                          -1
# ...

# %%
#Lectura/carga de datos	Limpieza de los datos	Estdistica de los datos
#pd.read_csv()	            pd.head()	        pd.describe()
#pd.read_table()	        pd.fillna()	        df.sample()
#pd.read_excel()	        pd.dropna()	        pd.mean()
#pd.read_sql()	            pd.sort_values()	pd.median()
#pd.read_json()	            pd.groupby()	    pd.std()
#pd.to_csv()	            pd.apply()	        pd.min()
#pd.DataFrame()	            pd.append()	        pd.max()
#pd.concat()	            pd.rename()	        pd.count()
#pd.Series()	            pd.set_index()	    pd.corr()
#pd.DataFrame.from_dict()	pd.tail()	        pd.hist()
